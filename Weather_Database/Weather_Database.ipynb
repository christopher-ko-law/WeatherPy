# %% [markdown]
# ## Deliverable 1. Retrieve Weather Data

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# import requests
import requests

# Import api key
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime
import time

# %%
# Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 766

# %%
# Create the base URL
url = "http://api.openweathermap.org/data/2.5/weather?APPID=" + weather_api_key

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city, and set the units to metric.
    city_url = url + "&units=metric&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        time.sleep(1)
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_desc,
                          "Country": city_country
                          })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Lata  40.1629   -8.3327     19.40        85           7
# 1     Sunndalsora  62.6754    8.5515     10.03        80          82
# 2           Bluff -46.6000  168.3333      9.89        90         100
# 3           Vaini -21.2000 -175.2000     21.09        94          90
# 4   Marsh Harbour  26.5412  -77.0636     26.04        77          66
# 5  Chernyshevskiy  63.0128  112.4714     14.45        53          60
# 6          Albany  42.6001  -73.9662      8.98        93         100
# 7            Miri   4.4148  114.0089     24.08       100          20
# 8      Bredasdorp -34.5322   20.0403      7.62        93          83
# 9       Busselton -33.6500  115.3333     11.16        67          92
#
#    Wind Speed Current Description Country
# 0        0.97           clear sky      PT
# 1        0.08       broken clouds      NO
# 2        9.78     overcast clouds      NZ
# 3        3.09       moderate rain      TO
# 4        5.50       broken clouds      BS
# 5        1.99       broken clouds      RU
# 6        2.50       moderate rain      US
# 7        1.53          few clouds      MY
# 8        1.56       broken clouds      ZA
# 9        5.95     overcast clouds      AU

# %%
# New column order
new_column_order = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df = city_data_df[new_column_order]
# Out:
#  Record 17 of Set 7 | srednekolymsk
# Processing Record 18 of Set 7 | hambantota
# Processing Record 19 of Set 7 | kodiak
# Processing Record 20 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 21 of Set 7 | ahipara
# Processing Record 22 of Set 7 | alice
# Processing Record 23 of Set 7 | lumberton
# Processing Record 24 of Set 7 | urumqi
# Processing Record 25 of Set 7 | liku
# Processing Record 26 of Set 7 | safwah
# City not found. Skipping...
# Processing Record 27 of Set 7 | gamba
# Processing Record 28 of Set 7 | esperance
# Processing Record 29 of Set 7 | saint-georges
# Processing Record 30 of Set 7 | sisimiut
# Processing Record 31 of Set 7 | bhag
# Processing Record 32 of Set 7 | aksay
# Processing Record 33 of Set 7 | elko
# Processing Record 34 of Set 7 | hit
# Processing Record 35 of Set 7 | kathmandu
# Processing Record 36 of Set 7 | san patricio
# Processing Record 37 of Set 7 | shebunino
# Processing Record 38 of Set 7 | tuatapere
# Processing Record 39 of Set 7 | yumen
# Processing Record 40 of Set 7 | khasan
# Processing Record 41 of Set 7 | umea
# Processing Record 42 of Set 7 | magadan
# Processing Record 43 of Set 7 | freeport
# Processing Record 44 of Set 7 | yasnogorsk
# Processing Record 45 of Set 7 | tairua
# Processing Record 46 of Set 7 | los llanos de aridane
# Processing Record 47 of Set 7 | saint anthony
# Processing Record 48 of Set 7 | lorengau
# Processing Record 49 of Set 7 | peterhead
# Processing Record 50 of Set 7 | coquimbo
# Processing Record 1 of Set 8 | el progreso
# Processing Record 2 of Set 8 | ahuimanu
# Processing Record 3 of Set 8 | kozmodemyansk
# Processing Record 4 of Set 8 | hearst
# Processing Record 5 of Set 8 | ilo
# Processing Record 6 of Set 8 | catalina
# Processing Record 7 of Set 8 | scottsbluff
# Processing Record 8 of Set 8 | jalu
# Processing Record 9 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 10 of Set 8 | ponta delgada
# Processing Record 11 of Set 8 | amapa
# Processing Record 12 of Set 8 | sao joao da barra
# Processing Record 13 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 14 of Set 8 | aberdeen
# Processing Record 15 of Set 8 | santander de quilichao
# Processing Record 16 of Set 8 | cheuskiny
# City not found. Skipping...
# Processing Record 17 of Set 8 | ocampo
# Processing Record 18 of Set 8 | mushabani
# Processing Record 19 of Set 8 | stephenville
# Processing Record 20 of Set 8 | havre
# Processing Record 21 of Set 8 | vallenar
# Processing Record 22 of Set 8 | quatre cocos
# Processing Record 23 of Set 8 | altay
# Processing Record 24 of Set 8 | qasigiannguit
# Processing Record 25 of Set 8 | beinamar
# Processing Record 26 of Set 8 | oktyabrskoye
# Processing Record 27 of Set 8 | vouliagmeni
# Processing Record 28 of Set 8 | shuyskoye
# Processing Record 29 of Set 8 | bechem
# Processing Record 30 of Set 8 | semporna
# Processing Record 31 of Set 8 | baruun-urt
# Processing Record 32 of Set 8 | saint-pierre
# Processing Record 33 of Set 8 | artvin
# Processing Record 34 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 35 of Set 8 | tra vinh
# Processing Record 36 of Set 8 | tanout
# Processing Record 37 of Set 8 | guerrero negro
# Processing Record 38 of Set 8 | manadhoo
# Processing Record 39 of Set 8 | asau
# Processing Record 40 of Set 8 | sault sainte marie
# Processing Record 41 of Set 8 | litovko
# Processing Record 42 of Set 8 | bani walid
# Processing Record 43 of Set 8 | kutum
# Processing Record 44 of Set 8 | olafsvik
# Processing Record 45 of Set 8 | makakilo city
# Processing Record 46 of Set 8 | puerto del rosario
# Processing Record 47 of Set 8 | ariquemes
# Processing Record 48 of Set 8 | kongolo
# Processing Record 49 of Set 8 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 50 of Set 8 | kokoda
# Processing Record 1 of Set 9 | luderitz
# Processing Record 2 of Set 9 | cayenne
# Processing Record 3 of Set 9 | vao
# Processing Record 4 of Set 9 | gorontalo
# Processing Record 5 of Set 9 | sola
# Processing Record 6 of Set 9 | livny
# Processing Record 7 of Set 9 | thinadhoo
# Processing Record 8 of Set 9 | mackay
# Processing Record 9 of Set 9 | dunedin
# Processing Record 10 of Set 9 | agadez
# Processing Record 11 of Set 9 | kazanka
# Processing Record 12 of Set 9 | voyinka
# Processing Record 13 of Set 9 | peniche
# Processing Record 14 of Set 9 | bandarbeyla
# Processing Record 15 of Set 9 | agadir
# Processing Record 16 of Set 9 | andevoranto
# City not found. Skipping...
# Processing Record 17 of Set 9 | tygda
# Processing Record 18 of Set 9 | devils lake
# Processing Record 19 of Set 9 | chuy
# Processing Record 20 of Set 9 | mananjary
# Processing Record 21 of Set 9 | kailua
# Processing Record 22 of Set 9 | marilandia
# Processing Record 23 of Set 9 | glinka
# Processing Record 24 of Set 9 | padilla
# Processing Record 25 of Set 9 | tateyama
# Processing Record 26 of Set 9 | dukat
# Processing Record 27 of Set 9 | bac lieu
# Processing Record 28 of Set 9 | miranorte
# City not found. Skipping...
# Processing Record 29 of Set 9 | nouadhibou
# Processing Record 30 of Set 9 | inyonga
# Processing Record 31 of Set 9 | udachnyy
# Processing Record 32 of Set 9 | ankazoabo
# Processing Record 33 of Set 9 | cabedelo
# Processing Record 34 of Set 9 | pangoa
# Processing Record 35 of Set 9 | inhambane
# Processing Record 36 of Set 9 | tamandare
# Processing Record 37 of Set 9 | port pirie
# Processing Record 38 of Set 9 | flinders
# Processing Record 39 of Set 9 | bhigvan
# Processing Record 40 of Set 9 | salym
# Processing Record 41 of Set 9 | latung
# Processing Record 42 of Set 9 | namibe
# Processing Record 43 of Set 9 | chongoyape
# Processing Record 44 of Set 9 | ivdel
# Processing Record 45 of Set 9 | sayyan
# Processing Record 46 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 47 of Set 9 | winnemucca
# Processing Record 48 of Set 9 | carutapera
# Processing Record 49 of Set 9 | sao jose de ribamar
# Processing Record 50 of Set 9 | shenjiamen
# Processing Record 1 of Set 10 | asyut
# Processing Record 2 of Set 10 | shelburne
# Processing Record 3 of Set 10 | gravdal
# Processing Record 4 of Set 10 | tevriz
# Processing Record 5 of Set 10 | chodavaram
# Processing Record 6 of Set 10 | ngaoundere
# Processing Record 7 of Set 10 | kotma
# Processing Record 8 of Set 10 | wilmington
# Processing Record 9 of Set 10 | mocuba
# Processing Record 10 of Set 10 | souillac
# Processing Record 11 of Set 10 | bayangol
# Processing Record 12 of Set 10 | broken hill
# Processing Record 13 of Set 10 | salamiyah
# Processing Record 14 of Set 10 | lamu
# Processing Record 15 of Set 10 | kousseri
# Processing Record 16 of Set 10 | pacifica
# Processing Record 17 of Set 10 | estevan
# Processing Record 18 of Set 10 | blythe
# Processing Record 19 of Set 10 | shache
# Processing Record 20 of Set 10 | grootfontein
# Processing Record 21 of Set 10 | pachino
# Processing Record 22 of Set 10 | syracuse
# Processing Record 23 of Set 10 | korla
# Processing Record 24 of Set 10 | bukama
# Processing Record 25 of Set 10 | bereda
# Processing Record 26 of Set 10 | wuchi
# Processing Record 27 of Set 10 | fergus falls
# Processing Record 28 of Set 10 | kudahuvadhoo
# Processing Record 29 of Set 10 | nalut
# Processing Record 30 of Set 10 | dori
# Processing Record 31 of Set 10 | queimadas
# Processing Record 32 of Set 10 | camalu
# Processing Record 33 of Set 10 | afmadu
# City not found. Skipping...
# Processing Record 34 of Set 10 | boffa
# Processing Record 35 of Set 10 | texarkana
# Processing Record 36 of Set 10 | vostok
# Processing Record 37 of Set 10 | havelock
# Processing Record 38 of Set 10 | rafraf
# Processing Record 39 of Set 10 | deputatskiy
# Processing Record 40 of Set 10 | oakdale
# Processing Record 41 of Set 10 | tual
# Processing Record 42 of Set 10 | seymchan
# Processing Record 43 of Set 10 | mocambique
# City not found. Skipping...
# Processing Record 44 of Set 10 | ricardo palma
# Processing Record 45 of Set 10 | praia
# Processing Record 46 of Set 10 | iskateley
# Processing Record 47 of Set 10 | port macquarie
# Processing Record 48 of Set 10 | dolbeau
# City not found. Skipping...
# Processing Record 49 of Set 10 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 50 of Set 10 | trincomalee
# Processing Record 1 of Set 11 | chitral
# Processing Record 2 of Set 11 | sambava
# Processing Record 3 of Set 11 | hami
# Processing Record 4 of Set 11 | mangrol
# Processing Record 5 of Set 11 | khandbari
# Processing Record 6 of Set 11 | kulhudhuffushi
# Processing Record 7 of Set 11 | cocobeach
# Processing Record 8 of Set 11 | phek
# Processing Record 9 of Set 11 | nhulunbuy
# Processing Record 10 of Set 11 | kasongo
# Processing Record 11 of Set 11 | kotka
# Processing Record 12 of Set 11 | xuddur
# Processing Record 13 of Set 11 | elizabeth city
# Processing Record 14 of Set 11 | bonthe
# Processing Record 15 of Set 11 | grand gaube
# Processing Record 16 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 17 of Set 11 | polson
# Processing Record 18 of Set 11 | caravelas
# Processing Record 19 of Set 11 | kortkeros
# Processing Record 20 of Set 11 | ouro preto do oeste
# Processing Record 21 of Set 11 | tsihombe
# City not found. Skipping...
# Processing Record 22 of Set 11 | atbasar
# Processing Record 23 of Set 11 | arona
# Processing Record 24 of Set 11 | hay river
# Processing Record 25 of Set 11 | itarema
# Processing Record 26 of Set 11 | gariaband
# Processing Record 27 of Set 11 | kozhva
# Processing Record 28 of Set 11 | lafia
# Processing Record 29 of Set 11 | guliston
# Processing Record 30 of Set 11 | berea
# Processing Record 31 of Set 11 | alekseyevka
# Processing Record 32 of Set 11 | barceloneta
# Processing Record 33 of Set 11 | rio gallegos
# Processing Record 34 of Set 11 | jackson
# Processing Record 35 of Set 11 | iquique
# Processing Record 36 of Set 11 | panama city
# Processing Record 37 of Set 11 | gulshat
# City not found. Skipping...
# Processing Record 38 of Set 11 | torbay
# Processing Record 39 of Set 11 | medicine hat
# Processing Record 40 of Set 11 | bathsheba
# Processing Record 41 of Set 11 | ancud
# Processing Record 42 of Set 11 | college
# Processing Record 43 of Set 11 | moron
# Processing Record 44 of Set 11 | ixtapa
# Processing Record 45 of Set 11 | verkhnevilyuysk
# Processing Record 46 of Set 11 | primo tapia
# Processing Record 47 of Set 11 | geraldton
# Processing Record 48 of Set 11 | dhamtari
# Processing Record 49 of Set 11 | hutchinson
# Processing Record 50 of Set 11 | parrita
# Processing Record 1 of Set 12 | beni
# Processing Record 2 of Set 12 | play cu
# City not found. Skipping...
# Processing Record 3 of Set 12 | porto novo
# Processing Record 4 of Set 12 | broome
# Processing Record 5 of Set 12 | chapais
# Processing Record 6 of Set 12 | alekseyevsk
# Processing Record 7 of Set 12 | canora
# Processing Record 8 of Set 12 | yemelyanovo
# Processing Record 9 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 10 of Set 12 | jumla
# Processing Record 11 of Set 12 | gimli
# Processing Record 12 of Set 12 | deventer
# Processing Record 13 of Set 12 | kremenchuk
# Processing Record 14 of Set 12 | kerouane
# Processing Record 15 of Set 12 | sechura
# Processing Record 16 of Set 12 | willowmore
# Processing Record 17 of Set 12 | adre
# Processing Record 18 of Set 12 | cairns
# Processing Record 19 of Set 12 | poum
# Processing Record 20 of Set 12 | tema
# Processing Record 21 of Set 12 | kawana waters
# City not found. Skipping...
# Processing Record 22 of Set 12 | svatove
# Processing Record 23 of Set 12 | coahuayana
# Processing Record 24 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 25 of Set 12 | magetan
# City not found. Skipping...
# Processing Record 26 of Set 12 | llanes
# Processing Record 27 of Set 12 | gallup
# Processing Record 28 of Set 12 | kaeo
# Processing Record 29 of Set 12 | uhlove
# Processing Record 30 of Set 12 | tempio pausania
# Processing Record 31 of Set 12 | samarai
# Processing Record 32 of Set 12 | dong hoi
# Processing Record 33 of Set 12 | kuala terengganu
# Processing Record 34 of Set 12 | wuda
# Processing Record 35 of Set 12 | vila velha
# Processing Record 36 of Set 12 | houma
# Processing Record 37 of Set 12 | gat
# Processing Record 38 of Set 12 | wasilla
# Processing Record 39 of Set 12 | vung tau
# Processing Record 40 of Set 12 | sakakah
# Processing Record 41 of Set 12 | komsomolskiy
# Processing Record 42 of Set 12 | kochubey
# Processing Record 43 of Set 12 | mega
# Processing Record 44 of Set 12 | cochrane
# Processing Record 45 of Set 12 | da lat
# Processing Record 46 of Set 12 | san lorenzo
# Processing Record 47 of Set 12 | fevralsk
# City not found. Skipping...
# Processing Record 48 of Set 12 | manta
# Processing Record 49 of Set 12 | dongsheng
# Processing Record 50 of Set 12 | kasongo-lunda
# Processing Record 1 of Set 13 | bogashevo
# Processing Record 2 of Set 13 | raiganj
# Processing Record 3 of Set 13 | barawe
# City not found. Skipping...
# Processing Record 4 of Set 13 | lae
# Processing Record 5 of Set 13 | gwanda
# Processing Record 6 of Set 13 | joura
# Processing Record 7 of Set 13 | hanko
# Processing Record 8 of Set 13 | andenes
# Processing Record 9 of Set 13 | saint-francois
# Processing Record 10 of Set 13 | lasa
# Processing Record 11 of Set 13 | sal rei
# Processing Record 12 of Set 13 | berlevag
# Processing Record 13 of Set 13 | klaksvik
# Processing Record 14 of Set 13 | pangai
# Processing Record 15 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 16 of Set 13 | quakenbruck
# Processing Record 17 of Set 13 | tsiroanomandidy
# Processing Record 18 of Set 13 | netrakona
# Processing Record 19 of Set 13 | launceston
# Processing Record 20 of Set 13 | beringovskiy
# Processing Record 21 of Set 13 | high level
# Processing Record 22 of Set 13 | dumai
# Processing Record 23 of Set 13 | gari
# Processing Record 24 of Set 13 | nueva loja
# Processing Record 25 of Set 13 | sorland
# Processing Record 26 of Set 13 | dickinson
# Processing Record 27 of Set 13 | puerto escondido
# Processing Record 28 of Set 13 | praia da vitoria
# Processing Record 29 of Set 13 | vila do maio
# Processing Record 30 of Set 13 | stromness
# Processing Record 31 of Set 13 | sterling
# Processing Record 32 of Set 13 | vila praia de ancora
# Processing Record 33 of Set 13 | moranbah
# Processing Record 34 of Set 13 | half moon bay
# Processing Record 35 of Set 13 | pelym
# Processing Record 36 of Set 13 | salinopolis
# Processing Record 37 of Set 13 | saryozek
# Processing Record 38 of Set 13 | samalaeulu
# City not found. Skipping...
# Processing Record 39 of Set 13 | nokaneng
# Processing Record 40 of Set 13 | zalantun
# Processing Record 41 of Set 13 | almaznyy
# Processing Record 42 of Set 13 | haines junction
# Processing Record 43 of Set 13 | honiara
# Processing Record 44 of Set 13 | vokhtoga
# Processing Record 45 of Set 13 | humberto de campos
# Processing Record 46 of Set 13 | the valley
# Processing Record 47 of Set 13 | sabana de torres
# Processing Record 48 of Set 13 | imeni babushkina
# Processing Record 49 of Set 13 | paytug
# City not found. Skipping...
# Processing Record 50 of Set 13 | chumikan
# Processing Record 1 of Set 14 | ambodifototra
# City not found. Skipping...
# Processing Record 2 of Set 14 | la ligua
# Processing Record 3 of Set 14 | neya
# Processing Record 4 of Set 14 | rognan
# Processing Record 5 of Set 14 | cankuzo
# Processing Record 6 of Set 14 | methven
# Processing Record 7 of Set 14 | gizo
# Processing Record 8 of Set 14 | conceicao do araguaia
# Processing Record 9 of Set 14 | auki
# Processing Record 10 of Set 14 | vaitape
# Processing Record 11 of Set 14 | el dorado
# Processing Record 12 of Set 14 | valer
# Processing Record 13 of Set 14 | lebanon
# Processing Record 14 of Set 14 | karpathos
# Processing Record 15 of Set 14 | creel
# Processing Record 16 of Set 14 | kuruman
# Processing Record 17 of Set 14 | kampot
# Processing Record 18 of Set 14 | goderich
# Processing Record 19 of Set 14 | sala
# Processing Record 20 of Set 14 | darnah
# Processing Record 21 of Set 14 | juegang
# Processing Record 22 of Set 14 | yenagoa
# Processing Record 23 of Set 14 | bambanglipuro
# Processing Record 24 of Set 14 | piacabucu
# Processing Record 25 of Set 14 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 26 of Set 14 | marsa matruh
# Processing Record 27 of Set 14 | mount isa
# Processing Record 28 of Set 14 | pavlovka
# Processing Record 29 of Set 14 | santa catarina de tepehuanes
# Processing Record 30 of Set 14 | maragogi
# Processing Record 31 of Set 14 | khorramshahr
# Processing Record 32 of Set 14 | ziarat
# Processing Record 33 of Set 14 | wanaka
# Processing Record 34 of Set 14 | wuhan
# Processing Record 35 of Set 14 | puri
# Processing Record 36 of Set 14 | tomatlan
# Processing Record 37 of Set 14 | kemijarvi
# Processing Record 38 of Set 14 | maruko
# Processing Record 39 of Set 14 | vadso
# Processing Record 40 of Set 14 | vila franca do campo
# Processing Record 41 of Set 14 | topolevo
# Processing Record 42 of Set 14 | ban nahin
# Processing Record 43 of Set 14 | mullaitivu
# City not found. Skipping...
# Processing Record 44 of Set 14 | saint-augustin
# Processing Record 45 of Set 14 | kidal
# Processing Record 46 of Set 14 | oleksandrivka
# Processing Record 47 of Set 14 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 48 of Set 14 | sztum
# Processing Record 49 of Set 14 | jibuti
# Processing Record 50 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 1 of Set 15 | ossora
# Processing Record 2 of Set 15 | cockburn harbour
# City not found. Skipping...
# Processing Record 3 of Set 15 | sioux lookout
# Processing Record 4 of Set 15 | batemans bay
# Processing Record 5 of Set 15 | vizinga
# Processing Record 6 of Set 15 | ust-kuyga
# Processing Record 7 of Set 15 | kaniama
# Processing Record 8 of Set 15 | navlya
# Processing Record 9 of Set 15 | abreus
# Processing Record 10 of Set 15 | santa luzia
# Processing Record 11 of Set 15 | bhalki
# Processing Record 12 of Set 15 | umba
# Processing Record 13 of Set 15 | port lincoln
# Processing Record 14 of Set 15 | garowe
# Processing Record 15 of Set 15 | diamantino
# Processing Record 16 of Set 15 | dhone
# Processing Record 17 of Set 15 | carapegua
# Processing Record 18 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 19 of Set 15 | itaituba
# Processing Record 20 of Set 15 | sorong
# Processing Record 21 of Set 15 | kuala selangor
# Processing Record 22 of Set 15 | kenai
# Processing Record 23 of Set 15 | vestmanna
# Processing Record 24 of Set 15 | la ronge
# Processing Record 25 of Set 15 | manavalakurichi
# Processing Record 26 of Set 15 | cap malheureux
# Processing Record 27 of Set 15 | chapleau
# Processing Record 28 of Set 15 | calatayud
# Processing Record 29 of Set 15 | custodia
# Processing Record 30 of Set 15 | tecoanapa
# Processing Record 31 of Set 15 | riberalta
# Processing Record 32 of Set 15 | yorkton
# Processing Record 33 of Set 15 | nyimba
# Processing Record 34 of Set 15 | riyadh
# Processing Record 35 of Set 15 | dingle
# Processing Record 36 of Set 15 | mozarlandia
# Processing Record 37 of Set 15 | rorvik
# Processing Record 38 of Set 15 | vreed en hoop
# City not found. Skipping...
# Processing Record 39 of Set 15 | kavaratti
# Processing Record 40 of Set 15 | xochihuehuetlan
# Processing Record 41 of Set 15 | hualmay
# Processing Record 42 of Set 15 | barroualie
# City not found. Skipping...
# Processing Record 43 of Set 15 | biasca
# Processing Record 44 of Set 15 | sorvag
# City not found. Skipping...
# Processing Record 45 of Set 15 | mundo nuevo
# Processing Record 46 of Set 15 | plattsburgh
# Processing Record 47 of Set 15 | ulaanbaatar
# Processing Record 48 of Set 15 | mandera
# Processing Record 49 of Set 15 | mampong
# Processing Record 50 of Set 15 | pandan
# Processing Record 1 of Set 16 | rio brilhante
# Processing Record 2 of Set 16 | cabadiangan
# Processing Record 3 of Set 16 | burnie
# Processing Record 4 of Set 16 | rawson
# Processing Record 5 of Set 16 | sistranda
# Processing Record 6 of Set 16 | kajiado
# Processing Record 7 of Set 16 | marsaxlokk
# Processing Record 8 of Set 16 | tupik
# Processing Record 9 of Set 16 | romans-sur-isere
# Processing Record 10 of Set 16 | namuac
# Processing Record 11 of Set 16 | bouar
# Processing Record 12 of Set 16 | halifax
# Processing Record 13 of Set 16 | arroyo
# Processing Record 14 of Set 16 | bud
# Processing Record 15 of Set 16 | horsham
# Processing Record 16 of Set 16 | homer
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Review DF
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Lata      PT  40.1629   -8.3327     19.40        85           7
# 1     Sunndalsora      NO  62.6754    8.5515     10.03        80          82
# 2           Bluff      NZ -46.6000  168.3333      9.89        90         100
# 3           Vaini      TO -21.2000 -175.2000     21.09        94          90
# 4   Marsh Harbour      BS  26.5412  -77.0636     26.04        77          66
# 5  Chernyshevskiy      RU  63.0128  112.4714     14.45        53          60
# 6          Albany      US  42.6001  -73.9662      8.98        93         100
# 7            Miri      MY   4.4148  114.0089     24.08       100          20
# 8      Bredasdorp      ZA -34.5322   20.0403      7.62        93          83
# 9       Busselton      AU -33.6500  115.3333     11.16        67          92
#
#    Wind Speed Current Description
# 0        0.97           clear sky
# 1        0.08       broken clouds
# 2        9.78     overcast clouds
# 3        3.09       moderate rain
# 4        5.50       broken clouds
# 5        1.99       broken clouds
# 6        2.50       moderate rain
# 7        1.53          few clouds
# 8        1.56       broken clouds
# 9        5.95     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
